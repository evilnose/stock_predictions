# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from definitions import root

# %%
price_file = './data/apple_prices.csv'
prices = pd.read_csv(price_file, encoding='utf-8', parse_dates=['date'])

# %%
prices['price'].plot()
